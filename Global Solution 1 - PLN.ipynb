# %% [markdown]
# # **GLOBAL SOLUTION 1 - PLN**
#
# ---
#
#
# INTEGRANTES:
#
# * Henrique Marra Barbosa - RM97672
#
# * Arthur Hieda Cunha - RM551882
#
# * Lucas Bueno Taets Gustavo - RM552162

# %% [markdown]
# > Instalando bibliotecas

# %%
# !pip install textblob
# !pip install vaderSentiment
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# !pip install geopy
# !pip install pandas
# !pip install ipython
# Out:
# Requirement already satisfied: textblob in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: nltk>=3.8 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.8->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.8->textblob) (2024.5.10)
# Requirement already satisfied: tqdm in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.8->textblob) (4.66.1)
# Requirement already satisfied: colorama in c:\users\marra\appdata\roaming\python\python311\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# Requirement already satisfied: vaderSentiment in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (3.3.2)
# Requirement already satisfied: requests in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from vaderSentiment) (2.30.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from requests->vaderSentiment) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from requests->vaderSentiment) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from requests->vaderSentiment) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from requests->vaderSentiment) (2023.5.7)
# Requirement already satisfied: spacy in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.30.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (2.7.1)
# Requirement already satisfied: jinja2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (69.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: colorama in c:\users\marra\appdata\roaming\python\python311\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from jinja2->spacy) (2.1.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.0)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/12.8 MB 4.3 MB/s eta 0:00:03
#      --- ------------------------------------ 1.1/12.8 MB 14.6 MB/s eta 0:00:01
#      ---------- ----------------------------- 3.4/12.8 MB 27.2 MB/s eta 0:00:01
#      --------------------- ------------------ 7.0/12.8 MB 40.7 MB/s eta 0:00:01
#      ------------------------------ --------- 9.8/12.8 MB 45.0 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 72.6 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 65.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.30.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.1)
# Requirement already satisfied: jinja2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (69.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\marra\appdata\roaming\python\python311\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.0)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Requirement already satisfied: geopy in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from geopy) (2.0)
# Requirement already satisfied: pandas in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: ipython in c:\users\marra\appdata\roaming\python\python311\site-packages (8.14.0)
# Requirement already satisfied: backcall in c:\users\marra\appdata\roaming\python\python311\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: decorator in c:\users\marra\appdata\roaming\python\python311\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\marra\appdata\roaming\python\python311\site-packages (from ipython) (0.19.0)
# Requirement already satisfied: matplotlib-inline in c:\users\marra\appdata\roaming\python\python311\site-packages (from ipython) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\marra\appdata\roaming\python\python311\site-packages (from ipython) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\marra\appdata\roaming\python\python311\site-packages (from ipython) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\marra\appdata\roaming\python\python311\site-packages (from ipython) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\marra\appdata\roaming\python\python311\site-packages (from ipython) (0.6.2)
# Requirement already satisfied: traitlets>=5 in c:\users\marra\appdata\roaming\python\python311\site-packages (from ipython) (5.9.0)
# Requirement already satisfied: colorama in c:\users\marra\appdata\roaming\python\python311\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\marra\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\marra\appdata\roaming\python\python311\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\marra\appdata\roaming\python\python311\site-packages (from stack-data->ipython) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\marra\appdata\roaming\python\python311\site-packages (from stack-data->ipython) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\marra\appdata\roaming\python\python311\site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: six in c:\users\marra\appdata\local\programs\python\python311\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)

# %% [markdown]
# > Importando

# %%
# Imports necessários
import json
import spacy
from geopy.geocoders import Nominatim
import pandas as pd
from IPython.display import display
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %% [markdown]
# > Base de dados

# %%
# Carregar tweets do arquivo JSON
with open('tweets.json', 'r') as file:
    tweets = json.load(file)

# %% [markdown]
# > Extração de dados

# %%
# Análise de Sentimento usando Vader
analyzer = SentimentIntensityAnalyzer()

def analyze_sentiment(tweet):
    vs = analyzer.polarity_scores(tweet)
    polarity = vs['compound']
    
    # Definindo a categoria do sentimento
    if polarity > 0.05:
        sentiment_category = 'Positive'
    elif polarity < -0.05:
        sentiment_category = 'Negative'
    else:
        sentiment_category = 'Neutral'
        
    return polarity, sentiment_category


# Extração de Informações
nlp = spacy.load('en_core_web_sm')

def extract_information(tweet):
    doc = nlp(tweet)
    locations = [ent.text for ent in doc.ents if ent.label_ in ['GPE', 'LOC']]
    persons = [ent.text for ent in doc.ents if ent.label_ == 'PERSON']
    organizations = [ent.text for ent in doc.ents if ent.label_ == 'ORG']
    return locations, persons, organizations

# Geolocalização
geolocator = Nominatim(user_agent="abcd")

def get_coordinates(location):
    try:
        loc = geolocator.geocode(location)
        return (loc.latitude, loc.longitude) if loc else (None, None)
    except Exception as e:
        return (None, None)

# %%
# Processar tweets
tweet_data = []
location_cache = {}

for tweet in tweets:
    sentiment = analyze_sentiment(tweet)
    info = extract_information(tweet)
    coordinates = []
    for loc in info[0]:
        if loc not in location_cache:
            location_cache[loc] = get_coordinates(loc)
        coordinates.append(location_cache[loc])
    tweet_data.append({
        'Tweet': tweet,
        'Polarity': sentiment[0],
        'Sentiment Category': sentiment[1],
        'Locations': info[0],
        'Persons': info[1],
        'Organizations': info[2],
        'Coordinates': coordinates
    })

# %% [markdown]
# > Criando o dataframe

# %%
# Converter para DataFrame
df = pd.DataFrame(tweet_data)

# Função para exibir DataFrame com formatação bonita
def display_dataframe(df):
    styled_df = df.style.set_table_styles(
        [{'selector': 'th',
          'props': [('background-color', '#f2f2f2'),
                    ('color', 'black'),
                    ('font-weight', 'bold')]},
         {'selector': 'tr:nth-child(even)',
          'props': [('background-color', '#f9f9f9')]},
         {'selector': 'tr:nth-child(odd)',
          'props': [('background-color', 'white')]}]
    ).set_properties(**{'text-align': 'left', 'padding': '10px'})
    
    display(styled_df)

# Salvar em CSV
df.to_csv('tweet_analysis.csv', index=False)

# Exibir DataFrame formatado
display_dataframe(df)
# Out:
# <style type="text/css">
# #T_07146 th {
#   background-color: #f2f2f2;
#   color: black;
#   font-weight: bold;
# }
# #T_07146 tr:nth-child(even) {
#   background-color: #f9f9f9;
# }
# #T_07146 tr:nth-child(odd) {
#   background-color: white;
# }
# #T_07146_row0_col0, #T_07146_row0_col1, #T_07146_row0_col2, #T_07146_row0_col3, #T_07146_row0_col4, #T_07146_row0_col5, #T_07146_row0_col6, #T_07146_row1_col0, #T_07146_row1_col1, #T_07146_row1_col2, #T_07146_row1_col3, #T_07146_row1_col4, #T_07146_row1_col5, #T_07146_row1_col6, #T_07146_row2_col0, #T_07146_row2_col1, #T_07146_row2_col2, #T_07146_row2_col3, #T_07146_row2_col4, #T_07146_row2_col5, #T_07146_row2_col6, #T_07146_row3_col0, #T_07146_row3_col1, #T_07146_row3_col2, #T_07146_row3_col3, #T_07146_row3_col4, #T_07146_row3_col5, #T_07146_row3_col6, #T_07146_row4_col0, #T_07146_row4_col1, #T_07146_row4_col2, #T_07146_row4_col3, #T_07146_row4_col4, #T_07146_row4_col5, #T_07146_row4_col6, #T_07146_row5_col0, #T_07146_row5_col1, #T_07146_row5_col2, #T_07146_row5_col3, #T_07146_row5_col4, #T_07146_row5_col5, #T_07146_row5_col6, #T_07146_row6_col0, #T_07146_row6_col1, #T_07146_row6_col2, #T_07146_row6_col3, #T_07146_row6_col4, #T_07146_row6_col5, #T_07146_row6_col6, #T_07146_row7_col0, #T_07146_row7_col1, #T_07146_row7_col2, #T_07146_row7_col3, #T_07146_row7_col4, #T_07146_row7_col5, #T_07146_row7_col6, #T_07146_row8_col0, #T_07146_row8_col1, #T_07146_row8_col2, #T_07146_row8_col3, #T_07146_row8_col4, #T_07146_row8_col5, #T_07146_row8_col6, #T_07146_row9_col0, #T_07146_row9_col1, #T_07146_row9_col2, #T_07146_row9_col3, #T_07146_row9_col4, #T_07146_row9_col5, #T_07146_row9_col6, #T_07146_row10_col0, #T_07146_row10_col1, #T_07146_row10_col2, #T_07146_row10_col3, #T_07146_row10_col4, #T_07146_row10_col5, #T_07146_row10_col6, #T_07146_row11_col0, #T_07146_row11_col1, #T_07146_row11_col2, #T_07146_row11_col3, #T_07146_row11_col4, #T_07146_row11_col5, #T_07146_row11_col6, #T_07146_row12_col0, #T_07146_row12_col1, #T_07146_row12_col2, #T_07146_row12_col3, #T_07146_row12_col4, #T_07146_row12_col5, #T_07146_row12_col6, #T_07146_row13_col0, #T_07146_row13_col1, #T_07146_row13_col2, #T_07146_row13_col3, #T_07146_row13_col4, #T_07146_row13_col5, #T_07146_row13_col6, #T_07146_row14_col0, #T_07146_row14_col1, #T_07146_row14_col2, #T_07146_row14_col3, #T_07146_row14_col4, #T_07146_row14_col5, #T_07146_row14_col6, #T_07146_row15_col0, #T_07146_row15_col1, #T_07146_row15_col2, #T_07146_row15_col3, #T_07146_row15_col4, #T_07146_row15_col5, #T_07146_row15_col6, #T_07146_row16_col0, #T_07146_row16_col1, #T_07146_row16_col2, #T_07146_row16_col3, #T_07146_row16_col4, #T_07146_row16_col5, #T_07146_row16_col6, #T_07146_row17_col0, #T_07146_row17_col1, #T_07146_row17_col2, #T_07146_row17_col3, #T_07146_row17_col4, #T_07146_row17_col5, #T_07146_row17_col6, #T_07146_row18_col0, #T_07146_row18_col1, #T_07146_row18_col2, #T_07146_row18_col3, #T_07146_row18_col4, #T_07146_row18_col5, #T_07146_row18_col6, #T_07146_row19_col0, #T_07146_row19_col1, #T_07146_row19_col2, #T_07146_row19_col3, #T_07146_row19_col4, #T_07146_row19_col5, #T_07146_row19_col6 {
#   text-align: left;
#   padding: 10px;
# }
# </style>
# <table id="T_07146">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07146_level0_col0" class="col_heading level0 col0" >Tweet</th>
#       <th id="T_07146_level0_col1" class="col_heading level0 col1" >Polarity</th>
#       <th id="T_07146_level0_col2" class="col_heading level0 col2" >Sentiment Category</th>
#       <th id="T_07146_level0_col3" class="col_heading level0 col3" >Locations</th>
#       <th id="T_07146_level0_col4" class="col_heading level0 col4" >Persons</th>
#       <th id="T_07146_level0_col5" class="col_heading level0 col5" >Organizations</th>
#       <th id="T_07146_level0_col6" class="col_heading level0 col6" >Coordinates</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07146_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07146_row0_col0" class="data row0 col0" >There's a lot of plastic waste near the Great Barrier Reef. #OceanPollution</td>
#       <td id="T_07146_row0_col1" class="data row0 col1" >0.202300</td>
#       <td id="T_07146_row0_col2" class="data row0 col2" >Positive</td>
#       <td id="T_07146_row0_col3" class="data row0 col3" >[]</td>
#       <td id="T_07146_row0_col4" class="data row0 col4" >[]</td>
#       <td id="T_07146_row0_col5" class="data row0 col5" >[]</td>
#       <td id="T_07146_row0_col6" class="data row0 col6" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_07146_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07146_row1_col0" class="data row1 col0" >Saw oil spill near the coast of California. Authorities should act quickly! #SaveOurOceans</td>
#       <td id="T_07146_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_07146_row1_col2" class="data row1 col2" >Neutral</td>
#       <td id="T_07146_row1_col3" class="data row1 col3" >['California']</td>
#       <td id="T_07146_row1_col4" class="data row1 col4" >[]</td>
#       <td id="T_07146_row1_col5" class="data row1 col5" >[]</td>
#       <td id="T_07146_row1_col6" class="data row1 col6" >[(None, None)]</td>
#     </tr>
#     <tr>
#       <th id="T_07146_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_07146_row2_col0" class="data row2 col0" >Illegal dumping of waste by a company in the Gulf of Mexico. This needs to stop! #CleanSeas</td>
#       <td id="T_07146_row2_col1" class="data row2 col1" >-0.880500</td>
#       <td id="T_07146_row2_col2" class="data row2 col2" >Negative</td>
#       <td id="T_07146_row2_col3" class="data row2 col3" >['the Gulf of Mexico']</td>
#       <td id="T_07146_row2_col4" class="data row2 col4" >[]</td>
#       <td id="T_07146_row2_col5" class="data row2 col5" >[]</td>
#       <td id="T_07146_row2_col6" class="data row2 col6" >[(None, None)]</td>
#     </tr>
#     <tr>
#       <th id="T_07146_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_07146_row3_col0" class="data row3 col0" >Plastic bottles and bags are all over the beach in Miami. #PollutionAlert</td>
#       <td id="T_07146_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_07146_row3_col2" class="data row3 col2" >Neutral</td>
#       <td id="T_07146_row3_col3" class="data row3 col3" >['Miami']</td>
#       <td id="T_07146_row3_col4" class="data row3 col4" >['PollutionAlert']</td>
#       <td id="T_07146_row3_col5" class="data row3 col5" >[]</td>
#       <td id="T_07146_row3_col6" class="data row3 col6" >[(25.7741728, -80.19362)]</td>
#     </tr>
#     <tr>
#       <th id="T_07146_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_07146_row4_col0" class="data row4 col0" >Fishermen spotted dumping waste in the Arabian Sea. Authorities must take action. #OceanCleanUp</td>
#       <td id="T_07146_row4_col1" class="data row4 col1" >-0.624900</td>
#       <td id="T_07146_row4_col2" class="data row4 col2" >Negative</td>
#       <td id="T_07146_row4_col3" class="data row4 col3" >['the Arabian Sea']</td>
#       <td id="T_07146_row4_col4" class="data row4 col4" >[]</td>
#       <td id="T_07146_row4_col5" class="data row4 col5" >[]</td>
#       <td id="T_07146_row4_col6" class="data row4 col6" >[(None, None)]</td>
#     </tr>
#     <tr>
#       <th id="T_07146_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_07146_row5_col0" class="data row5 col0" >A cruise ship was seen releasing waste into the Mediterranean Sea. #StopPollution</td>
#       <td id="T_07146_row5_col1" class="data row5 col1" >-0.421500</td>
#       <td id="T_07146_row5_col2" class="data row5 col2" >Negative</td>
#       <td id="T_07146_row5_col3" class="data row5 col3" >['the Mediterranean Sea']</td>
#       <td id="T_07146_row5_col4" class="data row5 col4" >[]</td>
#       <td id="T_07146_row5_col5" class="data row5 col5" >[]</td>
#       <td id="T_07146_row5_col6" class="data row5 col6" >[(None, None)]</td>
#     </tr>
#     <tr>
#       <th id="T_07146_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_07146_row6_col0" class="da
